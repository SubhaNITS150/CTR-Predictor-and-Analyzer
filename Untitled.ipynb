# %% [markdown]
# ## Image OCR Analysis

# %%
# !pip install easyocr opencv-python matplotlib pillow
# Out:
# Requirement already satisfied: easyocr in c:\users\subha\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: opencv-python in c:\users\subha\anaconda3\lib\site-packages (4.13.0.90)
# Requirement already satisfied: matplotlib in c:\users\subha\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: pillow in c:\users\subha\anaconda3\lib\site-packages (12.0.0)
# Requirement already satisfied: torch in c:\users\subha\anaconda3\lib\site-packages (from easyocr) (2.10.0)
# Requirement already satisfied: torchvision>=0.5 in c:\users\subha\anaconda3\lib\site-packages (from easyocr) (0.25.0)
# Requirement already satisfied: opencv-python-headless in c:\users\subha\anaconda3\lib\site-packages (from easyocr) (4.13.0.90)
# Requirement already satisfied: scipy in c:\users\subha\anaconda3\lib\site-packages (from easyocr) (1.16.3)
# Requirement already satisfied: numpy in c:\users\subha\anaconda3\lib\site-packages (from easyocr) (2.3.5)
# Requirement already satisfied: scikit-image in c:\users\subha\anaconda3\lib\site-packages (from easyocr) (0.25.2)
# Requirement already satisfied: python-bidi in c:\users\subha\anaconda3\lib\site-packages (from easyocr) (0.6.7)
# Requirement already satisfied: PyYAML in c:\users\subha\anaconda3\lib\site-packages (from easyocr) (6.0.3)
# Requirement already satisfied: Shapely in c:\users\subha\anaconda3\lib\site-packages (from easyocr) (2.1.2)
# Requirement already satisfied: pyclipper in c:\users\subha\anaconda3\lib\site-packages (from easyocr) (1.4.0)
# Requirement already satisfied: ninja in c:\users\subha\anaconda3\lib\site-packages (from easyocr) (1.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\subha\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\subha\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\subha\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\subha\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\subha\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\subha\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\subha\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\subha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: filelock in c:\users\subha\anaconda3\lib\site-packages (from torch->easyocr) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\subha\anaconda3\lib\site-packages (from torch->easyocr) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\subha\anaconda3\lib\site-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\subha\anaconda3\lib\site-packages (from torch->easyocr) (3.5)
# Requirement already satisfied: jinja2 in c:\users\subha\anaconda3\lib\site-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\subha\anaconda3\lib\site-packages (from torch->easyocr) (2025.10.0)
# Requirement already satisfied: setuptools in c:\users\subha\anaconda3\lib\site-packages (from torch->easyocr) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\subha\anaconda3\lib\site-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\subha\anaconda3\lib\site-packages (from jinja2->torch->easyocr) (3.0.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\subha\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\subha\anaconda3\lib\site-packages (from scikit-image->easyocr) (2025.10.4)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\subha\anaconda3\lib\site-packages (from scikit-image->easyocr) (0.4)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("images-dataset/p1/1/1.png")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(499.5), np.float64(499.5), np.float64(-0.5))

# %% [markdown]
# ## OCR

# %%
import easyocr

# %%
reader = easyocr.Reader(['en'], gpu=False)
results = reader.readtext(img)

for bbox, text, prob in results:
    print(f"{text}  | confidence: {prob:.2f}")
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# Blue_Shoes  | confidence: 0.50
# 25% Qff  | confidence: 0.89
# Free Shipping, Exchanges & Returns  | confidence: 0.73
# Blue Shoes at anesshoes coml Code: BLUE  | confidence: 0.68
# WWW anesshoes comlcolors  | confidence: 0.68

# %%
import numpy as np

img_box = img_rgb.copy()

for (bbox, text, prob) in results:
    pts = np.array(bbox, dtype=np.int32)
    cv2.polylines(img_box, [pts], True, (0,255,0), 2)
    cv2.putText(
        img_box, text,
        (pts[0][0], pts[0][1]-5),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.6, (255,0,0), 2
    )

plt.imshow(img_box)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(499.5), np.float64(499.5), np.float64(-0.5))

# %%
# Full text
full_text = " ".join([text for _, text, _ in results])
print(full_text)
# Out:
# Blue_Shoes 25% Qff Free Shipping, Exchanges & Returns Blue Shoes at anesshoes coml Code: BLUE WWW anesshoes comlcolors
