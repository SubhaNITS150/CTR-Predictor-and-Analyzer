# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-5.0.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: filelock in c:\users\subha\anaconda3\lib\site-packages (from transformers) (3.20.0)
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers)
#   Downloading huggingface_hub-1.3.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\subha\anaconda3\lib\site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\subha\anaconda3\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\subha\anaconda3\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\subha\anaconda3\lib\site-packages (from transformers) (2025.9.1)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typer-slim in c:\users\subha\anaconda3\lib\site-packages (from transformers) (0.21.1)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\subha\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\subha\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.10.0)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=1.3.0->transformers)
#   Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\subha\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: shellingham in c:\users\subha\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\subha\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\subha\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.10.0)
# Requirement already satisfied: certifi in c:\users\subha\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\subha\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\subha\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\subha\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: colorama in c:\users\subha\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\subha\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\subha\anaconda3\lib\site-packages (from typer-slim->transformers) (8.2.1)
# Downloading transformers-5.0.0-py3-none-any.whl (10.1 MB)
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.1 MB 952.2 kB/s eta 0:00:11
#    --- ------------------------------------ 0.8/10.1 MB 967.4 kB/s eta 0:00:10
#    --- ------------------------------------ 0.8/10.1 MB 967.4 kB/s eta 0:00:10
#    ---- ----------------------------------- 1.0/10.1 MB 927.6 kB/s eta 0:00:10
#    ---- ----------------------------------- 1.0/10.1 MB 927.6 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.3/10.1 MB 811.2 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.3/10.1 MB 811.2 kB/s eta 0:00:11
#    ------ --------------------------------- 1.6/10.1 MB 731.9 kB/s eta 0:00:12
#    ------ --------------------------------- 1.6/10.1 MB 731.9 kB/s eta 0:00:12
#    ------ --------------------------------- 1.6/10.1 MB 731.9 kB/s eta 0:00:12
#    ------- -------------------------------- 1.8/10.1 MB 699.9 kB/s eta 0:00:12
#    ------- -------------------------------- 1.8/10.1 MB 699.9 kB/s eta 0:00:12
#    -------- ------------------------------- 2.1/10.1 MB 657.4 kB/s eta 0:00:13
#    -------- ------------------------------- 2.1/10.1 MB 657.4 kB/s eta 0:00:13
#    --------- ------------------------------ 2.4/10.1 MB 653.5 kB/s eta 0:00:12
#    --------- ------------------------------ 2.4/10.1 MB 653.5 kB/s eta 0:00:12
#    ---------- ----------------------------- 2.6/10.1 MB 653.1 kB/s eta 0:00:12
#    ---------- ----------------------------- 2.6/10.1 MB 653.1 kB/s eta 0:00:12
#    ----------- ---------------------------- 2.9/10.1 MB 651.0 kB/s eta 0:00:12
#    ----------- ---------------------------- 2.9/10.1 MB 651.0 kB/s eta 0:00:12
#    ------------ --------------------------- 3.1/10.1 MB 661.0 kB/s eta 0:00:11
#    ------------- -------------------------- 3.4/10.1 MB 667.2 kB/s eta 0:00:11
#    ------------- -------------------------- 3.4/10.1 MB 667.2 kB/s eta 0:00:11
#    -------------- ------------------------- 3.7/10.1 MB 668.0 kB/s eta 0:00:10
#    -------------- ------------------------- 3.7/10.1 MB 668.0 kB/s eta 0:00:10
#    --------------- ------------------------ 3.9/10.1 MB 679.5 kB/s eta 0:00:10
#    ---------------- ----------------------- 4.2/10.1 MB 689.6 kB/s eta 0:00:09
#    ----------------- ---------------------- 4.5/10.1 MB 702.7 kB/s eta 0:00:09
#    ------------------ --------------------- 4.7/10.1 MB 721.4 kB/s eta 0:00:08
#    ------------------ --------------------- 4.7/10.1 MB 721.4 kB/s eta 0:00:08
#    ------------------- -------------------- 5.0/10.1 MB 729.9 kB/s eta 0:00:08
#    -------------------- ------------------- 5.2/10.1 MB 736.0 kB/s eta 0:00:07
#    --------------------- ------------------ 5.5/10.1 MB 747.1 kB/s eta 0:00:07
#    --------------------- ------------------ 5.5/10.1 MB 747.1 kB/s eta 0:00:07
#    ---------------------- ----------------- 5.8/10.1 MB 758.2 kB/s eta 0:00:06
#    ----------------------- ---------------- 6.0/10.1 MB 772.0 kB/s eta 0:00:06
#    ------------------------ --------------- 6.3/10.1 MB 784.0 kB/s eta 0:00:05
#    ------------------------- -------------- 6.6/10.1 MB 788.6 kB/s eta 0:00:05
#    -------------------------- ------------- 6.8/10.1 MB 797.4 kB/s eta 0:00:05
#    -------------------------- ------------- 6.8/10.1 MB 797.4 kB/s eta 0:00:05
#    --------------------------- ------------ 7.1/10.1 MB 788.3 kB/s eta 0:00:04
#    --------------------------- ------------ 7.1/10.1 MB 788.3 kB/s eta 0:00:04
#    ---------------------------- ----------- 7.3/10.1 MB 790.5 kB/s eta 0:00:04
#    ----------------------------- ---------- 7.6/10.1 MB 791.2 kB/s eta 0:00:04
#    ----------------------------- ---------- 7.6/10.1 MB 791.2 kB/s eta 0:00:04
#    ------------------------------- -------- 7.9/10.1 MB 793.2 kB/s eta 0:00:03
#    ------------------------------- -------- 7.9/10.1 MB 793.2 kB/s eta 0:00:03
#    -------------------------------- ------- 8.1/10.1 MB 786.0 kB/s eta 0:00:03
#    -------------------------------- ------- 8.1/10.1 MB 786.0 kB/s eta 0:00:03
#    --------------------------------- ------ 8.4/10.1 MB 776.7 kB/s eta 0:00:03
#    --------------------------------- ------ 8.4/10.1 MB 776.7 kB/s eta 0:00:03
#    --------------------------------- ------ 8.4/10.1 MB 776.7 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.7/10.1 MB 756.7 kB/s eta 0:00:02
#    ---------------------------------- ----- 8.7/10.1 MB 756.7 kB/s eta 0:00:02
#    ---------------------------------- ----- 8.7/10.1 MB 756.7 kB/s eta 0:00:02
#    ---------------------------------- ----- 8.7/10.1 MB 756.7 kB/s eta 0:00:02
#    ---------------------------------- ----- 8.7/10.1 MB 756.7 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.9/10.1 MB 706.6 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.9/10.1 MB 706.6 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.9/10.1 MB 706.6 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.9/10.1 MB 706.6 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.9/10.1 MB 706.6 kB/s eta 0:00:02
#    ------------------------------------ --- 9.2/10.1 MB 677.1 kB/s eta 0:00:02
#    ------------------------------------ --- 9.2/10.1 MB 677.1 kB/s eta 0:00:02
#    ------------------------------------ --- 9.2/10.1 MB 677.1 kB/s eta 0:00:02
#    ------------------------------------- -- 9.4/10.1 MB 663.8 kB/s eta 0:00:02
#    ------------------------------------- -- 9.4/10.1 MB 663.8 kB/s eta 0:00:02
#    ------------------------------------- -- 9.4/10.1 MB 663.8 kB/s eta 0:00:02
#    ------------------------------------- -- 9.4/10.1 MB 663.8 kB/s eta 0:00:02
#    -------------------------------------- - 9.7/10.1 MB 644.6 kB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.1 MB 644.6 kB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.1 MB 644.6 kB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.1 MB 644.6 kB/s eta 0:00:01
#    ---------------------------------------  10.0/10.1 MB 629.6 kB/s eta 0:00:01
#    ---------------------------------------  10.0/10.1 MB 629.6 kB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 622.5 kB/s  0:00:16
# Downloading huggingface_hub-1.3.4-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/536.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/536.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/536.6 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/536.6 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/536.6 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/536.6 kB ? eta -:--:--
#    ---------------------------------------- 536.6/536.6 kB 441.7 kB/s  0:00:01
# Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.9 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.9 MB 313.9 kB/s eta 0:00:08
#    ------- -------------------------------- 0.5/2.9 MB 313.9 kB/s eta 0:00:08
#    ---------- ----------------------------- 0.8/2.9 MB 398.7 kB/s eta 0:00:06
#    ---------- ----------------------------- 0.8/2.9 MB 398.7 kB/s eta 0:00:06
#    ---------- ----------------------------- 0.8/2.9 MB 398.7 kB/s eta 0:00:06
#    -------------- ------------------------- 1.0/2.9 MB 417.9 kB/s eta 0:00:05
#    -------------- ------------------------- 1.0/2.9 MB 417.9 kB/s eta 0:00:05
#    ------------------ --------------------- 1.3/2.9 MB 442.8 kB/s eta 0:00:04
#    ------------------ --------------------- 1.3/2.9 MB 442.8 kB/s eta 0:00:04
#    ------------------ --------------------- 1.3/2.9 MB 442.8 kB/s eta 0:00:04
#    ------------------ --------------------- 1.3/2.9 MB 442.8 kB/s eta 0:00:04
#    --------------------- ------------------ 1.6/2.9 MB 421.1 kB/s eta 0:00:04
#    --------------------- ------------------ 1.6/2.9 MB 421.1 kB/s eta 0:00:04
#    ------------------------- -------------- 1.8/2.9 MB 446.0 kB/s eta 0:00:03
#    ---------------------------- ----------- 2.1/2.9 MB 474.8 kB/s eta 0:00:02
#    ---------------------------- ----------- 2.1/2.9 MB 474.8 kB/s eta 0:00:02
#    -------------------------------- ------- 2.4/2.9 MB 506.5 kB/s eta 0:00:02
#    -------------------------------- ------- 2.4/2.9 MB 506.5 kB/s eta 0:00:02
#    ------------------------------------ --- 2.6/2.9 MB 518.8 kB/s eta 0:00:01
#    ------------------------------------ --- 2.6/2.9 MB 518.8 kB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 521.4 kB/s  0:00:05
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 766.4 kB/s eta 0:00:03
#    ----------- ---------------------------- 0.8/2.7 MB 764.8 kB/s eta 0:00:03
#    ----------- ---------------------------- 0.8/2.7 MB 764.8 kB/s eta 0:00:03
#    --------------- ------------------------ 1.0/2.7 MB 710.8 kB/s eta 0:00:03
#    --------------- ------------------------ 1.0/2.7 MB 710.8 kB/s eta 0:00:03
#    ------------------- -------------------- 1.3/2.7 MB 711.3 kB/s eta 0:00:03
#    ------------------- -------------------- 1.3/2.7 MB 711.3 kB/s eta 0:00:03
#    ---------------------- ----------------- 1.6/2.7 MB 681.2 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.6/2.7 MB 681.2 kB/s eta 0:00:02
#    -------------------------- ------------- 1.8/2.7 MB 685.0 kB/s eta 0:00:02
#    -------------------------- ------------- 1.8/2.7 MB 685.0 kB/s eta 0:00:02
#    ------------------------------ --------- 2.1/2.7 MB 690.2 kB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.7 MB 690.2 kB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.7 MB 685.1 kB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.7 MB 685.1 kB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 684.1 kB/s  0:00:03
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Installing collected packages: safetensors, hf-xet, huggingface-hub, tokenizers, transformers
#
#    ---------------- ----------------------- 2/5 [huggingface-hub]
#    ---------------- ----------------------- 2/5 [huggingface-hub]
#    ---------------- ----------------------- 2/5 [huggingface-hub]
#    ---------------- ----------------------- 2/5 [huggingface-hub]
#    ---------------- ----------------------- 2/5 [huggingface-hub]
#    ------------------------ --------------- 3/5 [tokenizers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    -------------------------------- ------- 4/5 [transformers]
#    ---------------------------------------- 5/5 [transformers]
#
# Successfully installed hf-xet-1.2.0 huggingface-hub-1.3.4 safetensors-0.7.0 tokenizers-0.22.2 transformers-5.0.0

# %%
# !pip install sentence-transformers --quiet

# %%
# !pip install textstat --quiet

# %%
import re
import numpy as np
import pandas as pd
from transformers import pipeline
from sentence_transformers import SentenceTransformer, util
import textstat

# %% [markdown]
# ### Data Preprocessing

# %%
df = pd.read_csv("ads_creative_text_sample.csv")
df
# Out:
#                                                   text  dimensions
# 0    Up to\n$100 off\nroundtrip\nflights to\nIrelan...  (160, 600)
# 1    yp The Real\nур\nYellow Pages\nFind cheap\ngas...  (300, 250)
# 2    Food Navigator\nUSA\nPlant-based meat:\nBeyond...  (300, 600)
# 3    MONSTROUS\nAIRFLOW\n$20-$23\nDURAMAX\nbanks\n+...  (300, 250)
# 4    YUMMY\nCOMBS\n*\na\nNutriti\nWellne\nNOW\nSafe...   (728, 90)
# ..                                                 ...         ...
# 995  Ochrome OS\nDevice management\nmade simple and...  (300, 600)
# 996  Continue to Recipe\n3 Easy Steps:\n1) Click "C...  (336, 280)
# 997  WIN THIS HOUSE\nAND START\nEVERY DAY HERE\nAll...  (970, 250)
# 998  EVIDENT OLYMPUS\nSZX-AR1 Augmented\nReality Mi...  (300, 250)
# 999  Searching for Speakers?\nCompare\nBefore You B...  (300, 250)
#
# [1000 rows x 2 columns]

# %%
def clean_ad_text(text):
    text = text.replace("\n", " ")
    text = " ".join(text.split()) 
    return text

# %%
df["clean_text"] = df["text"].apply(clean_ad_text)
df[["text", "clean_text"]].head(5)
# Out:
#                                                 text  \
# 0  Up to\n$100 off\nroundtrip\nflights to\nIrelan...
# 1  yp The Real\nур\nYellow Pages\nFind cheap\ngas...
# 2  Food Navigator\nUSA\nPlant-based meat:\nBeyond...
# 3  MONSTROUS\nAIRFLOW\n$20-$23\nDURAMAX\nbanks\n+...
# 4  YUMMY\nCOMBS\n*\na\nNutriti\nWellne\nNOW\nSafe...
#
#                                           clean_text
# 0  Up to $100 off roundtrip flights to Ireland. T...
# 1  yp The Real ур Yellow Pages Find cheap gas nea...
# 2  Food Navigator USA Plant-based meat: Beyond th...
# 3  MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...
# 4  YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...

# %%
def capital_features(text):
    if not isinstance(text, str):
        text = ""

    words = text.split()
    num_words = len(words)
    caps_words = sum(1 for w in words if w.isupper() and len(w) > 1)
    capital_ratio = caps_words / num_words if num_words else 0
    num_exclamations = text.count("!")

    return pd.Series({
        "num_words": num_words,
        "num_caps_words": caps_words,
        "capital_ratio": min(capital_ratio, 0.6),
        "num_exclamations": num_exclamations
    })

# %%
cap_df = df["clean_text"].apply(capital_features)
cap_df
# Out:
#      num_words  num_caps_words  capital_ratio  num_exclamations
# 0         27.0             1.0       0.037037               0.0
# 1         51.0             5.0       0.098039               1.0
# 2         23.0            14.0       0.600000               0.0
# 3         27.0            11.0       0.407407               0.0
# 4         18.0             5.0       0.277778               2.0
# ..         ...             ...            ...               ...
# 995       22.0             1.0       0.045455               0.0
# 996       19.0             0.0       0.000000               1.0
# 997       15.0             8.0       0.533333               0.0
# 998       10.0             3.0       0.300000               0.0
# 999       13.0             2.0       0.153846               0.0
#
# [1000 rows x 4 columns]

# %%
df = pd.concat([df, cap_df], axis=1)

# %%
df.columns
# Out:
# Index(['text', 'dimensions', 'clean_text', 'num_words', 'num_caps_words',
#        'capital_ratio', 'num_exclamations'],
#       dtype='object')

# %%
df.head()
# Out:
#                                                 text  dimensions  \
# 0  Up to\n$100 off\nroundtrip\nflights to\nIrelan...  (160, 600)
# 1  yp The Real\nур\nYellow Pages\nFind cheap\ngas...  (300, 250)
# 2  Food Navigator\nUSA\nPlant-based meat:\nBeyond...  (300, 600)
# 3  MONSTROUS\nAIRFLOW\n$20-$23\nDURAMAX\nbanks\n+...  (300, 250)
# 4  YUMMY\nCOMBS\n*\na\nNutriti\nWellne\nNOW\nSafe...   (728, 90)
#
#                                           clean_text  num_words  \
# 0  Up to $100 off roundtrip flights to Ireland. T...       27.0
# 1  yp The Real ур Yellow Pages Find cheap gas nea...       51.0
# 2  Food Navigator USA Plant-based meat: Beyond th...       23.0
# 3  MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...       27.0
# 4  YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...       18.0
#
#    num_caps_words  capital_ratio  num_exclamations
# 0             1.0       0.037037               0.0
# 1             5.0       0.098039               1.0
# 2            14.0       0.600000               0.0
# 3            11.0       0.407407               0.0
# 4             5.0       0.277778               2.0

# %%
df.isna().sum()
# Out:
# text                0
# dimensions          0
# clean_text          0
# num_words           0
# num_caps_words      0
# capital_ratio       0
# num_exclamations    0
# dtype: int64

# %% [markdown]
# ### Cleaning of Clean_Text

# %%
df["clean_text"] = df["clean_text"].fillna("")

# %%
df["clean_text"].head(5)
# Out:
# 0    Up to $100 off roundtrip flights to Ireland. T...
# 1    yp The Real ур Yellow Pages Find cheap gas nea...
# 2    Food Navigator USA Plant-based meat: Beyond th...
# 3    MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...
# 4    YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...
# Name: clean_text, dtype: object

# %% [markdown]
# ### Twitter Roberta Sentiment Model

# %%
sentiment_pipe = pipeline(
    "sentiment-analysis",
    model="cardiffnlp/twitter-roberta-base-sentiment"
)
# Out:
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# C:\Users\subha\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:130: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\subha\.cache\huggingface\hub\models--cardiffnlp--twitter-roberta-base-sentiment. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-sentiment
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]

# %%
sentiment_pipe("LIMITED TIME OFFER! BUY ONE GET ONE FREE")
# Out:
# [{'label': 'LABEL_2', 'score': 0.7480954527854919}]

# %%
sentiment_pipe("Buy one Get one free")
# Out:
# [{'label': 'LABEL_1', 'score': 0.6027004718780518}]

# %%
def sentiment_score(text):
    if not isinstance(text, str) or text.strip() == "":
        return 0.5  # neutral fallback

    result = sentiment_pipe(text)[0]["label"]

    mapping = {
        "LABEL_2": 1.0,  # positive
        "LABEL_1": 0.5,  # neutral
        "LABEL_0": 0.0   # negative
    }

    return mapping[result]

# %%
df["sentiment_score_test"] = df["clean_text"].head(10).apply(sentiment_score)

# %%
df[["clean_text", "sentiment_score_test"]].head(10)
# Out:
#                                           clean_text  sentiment_score_test
# 0  Up to $100 off roundtrip flights to Ireland. T...                   0.5
# 1  yp The Real ур Yellow Pages Find cheap gas nea...                   0.5
# 2  Food Navigator USA Plant-based meat: Beyond th...                   0.5
# 3  MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...                   0.5
# 4  YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...                   1.0
# 5                        ROSELINLIN FREE SHIPPING 10                   0.5
# 6  MENARDS GIFT CARD MENARDS GIFT CARDS MEWARDS G...                   0.5
# 7  From Hello to Help, 211 is Here 2.1.1 Get Conn...                   0.5
# 8  ALL ABOUT CIRCUITS Need a Battery Refresher? 9...                   0.5
# 9  UNITED MileagePlus. Get ready and bon voyage U...                   0.5

# %%
df[["clean_text", "sentiment_score_test"]].head(10)
# Out:
#                                           clean_text  sentiment_score_test
# 0  Up to $100 off roundtrip flights to Ireland. T...                   0.5
# 1  yp The Real ур Yellow Pages Find cheap gas nea...                   0.5
# 2  Food Navigator USA Plant-based meat: Beyond th...                   0.5
# 3  MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...                   0.5
# 4  YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...                   1.0
# 5                        ROSELINLIN FREE SHIPPING 10                   0.5
# 6  MENARDS GIFT CARD MENARDS GIFT CARDS MEWARDS G...                   0.5
# 7  From Hello to Help, 211 is Here 2.1.1 Get Conn...                   0.5
# 8  ALL ABOUT CIRCUITS Need a Battery Refresher? 9...                   0.5
# 9  UNITED MileagePlus. Get ready and bon voyage U...                   0.5

# %%
df["sentiment_score"] = df["clean_text"].apply(sentiment_score)

# %%
df["sentiment_score"].value_counts()
# Out:
# sentiment_score
# 0.5    729
# 1.0    252
# 0.0     19
# Name: count, dtype: int64

# %%
df[["clean_text", "sentiment_score"]].sample(10)
# Out:
#                                             clean_text  sentiment_score
# 178  INTERACT WITH GQ BE A PART OF GOCOMMUNITY JOIN...              0.5
# 866  MARS 4K A 4K Wireless Video Transmission Syste...              0.5
# 221  goodness Celebrating all that's good. PG Spons...              1.0
# 907  Ponce Bank OF BESTTH BRONX PRESENTED BY PONCE ...              0.5
# 153  FANDANGO F FANDANGO we love movies F FANDANGO ...              1.0
# 718  FIND RARE PARTS THE ONLY EBAY STORE WHERE YOU ...              0.5
# 959  A mortgage.net Today's Refinance Rate 1.997 %*...              0.5
# 878  WHAT'S YOUR NEXT MOVE? Create your own headlin...              0.5
# 508  HERE COMES Santa Claus Friday, December 3 News...              0.5
# 513  Take a break from 'the usual' VISIT UPTOWNCHAR...              0.5

# %%
df.to_csv("ads_with_sentiment.csv", index=False)

# %%
df.head()
# Out:
#                                                 text  dimensions  \
# 0  Up to\n$100 off\nroundtrip\nflights to\nIrelan...  (160, 600)
# 1  yp The Real\nур\nYellow Pages\nFind cheap\ngas...  (300, 250)
# 2  Food Navigator\nUSA\nPlant-based meat:\nBeyond...  (300, 600)
# 3  MONSTROUS\nAIRFLOW\n$20-$23\nDURAMAX\nbanks\n+...  (300, 250)
# 4  YUMMY\nCOMBS\n*\na\nNutriti\nWellne\nNOW\nSafe...   (728, 90)
#
#                                           clean_text  num_words  \
# 0  Up to $100 off roundtrip flights to Ireland. T...       27.0
# 1  yp The Real ур Yellow Pages Find cheap gas nea...       51.0
# 2  Food Navigator USA Plant-based meat: Beyond th...       23.0
# 3  MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...       27.0
# 4  YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...       18.0
#
#    num_caps_words  capital_ratio  num_exclamations  sentiment_score_test  \
# 0             1.0       0.037037               0.0                   0.5
# 1             5.0       0.098039               1.0                   0.5
# 2            14.0       0.600000               0.0                   0.5
# 3            11.0       0.407407               0.0                   0.5
# 4             5.0       0.277778               2.0                   1.0
#
#    sentiment_score
# 0              0.5
# 1              0.5
# 2              0.5
# 3              0.5
# 4              1.0

# %% [markdown]
# ### Semantic Persuation Score

# %%
# sentence-transformers/all-MiniLM-L6-v2

# %%
df["clean_text"].head(5)
# Out:
# 0    Up to $100 off roundtrip flights to Ireland. T...
# 1    yp The Real ур Yellow Pages Find cheap gas nea...
# 2    Food Navigator USA Plant-based meat: Beyond th...
# 3    MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...
# 4    YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...
# Name: clean_text, dtype: object

# %%
df["clean_text"] = df["clean_text"].fillna("")

# %%
sbert = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\subha\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:130: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\subha\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
persuasion_anchors = [
    "limited time offer",
    "exclusive deal just for you",
    "win big prizes",
    "best price guaranteed",
    "don’t miss this opportunity",
    "start your journey today",
    "high quality product at discount"
]

# %%
anchor_embeddings = sbert.encode(
    persuasion_anchors,
    convert_to_tensor=True
)

# %%
### Test data frame
test_text = "LIMITED TIME OFFER! BUY NOW AND SAVE BIG"

test_emb = sbert.encode(test_text, convert_to_tensor=True)
similarity = util.cos_sim(test_emb, anchor_embeddings)

similarity
# Out:
# tensor([[0.7249, 0.3643, 0.2568, 0.3477, 0.1331, 0.0988, 0.2707]])

# %%
similarity.max().item()
# Out:
# 0.7248973846435547

# %%
def persuasion_score(text):
    if not isinstance(text, str) or text.strip() == "":
        return 0.0

    emb = sbert.encode(text, convert_to_tensor=True)
    sim = util.cos_sim(emb, anchor_embeddings).max().item()

    return float(np.clip(sim, 0, 1))

# %%
df["persuasion_score_test"] = df["clean_text"].head(10).apply(persuasion_score)
df[["clean_text", "persuasion_score_test"]].head(10)
# Out:
#                                           clean_text  persuasion_score_test
# 0  Up to $100 off roundtrip flights to Ireland. T...               0.198016
# 1  yp The Real ур Yellow Pages Find cheap gas nea...               0.222818
# 2  Food Navigator USA Plant-based meat: Beyond th...               0.151504
# 3  MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...               0.262872
# 4  YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...               0.172790
# 5                        ROSELINLIN FREE SHIPPING 10               0.294787
# 6  MENARDS GIFT CARD MENARDS GIFT CARDS MEWARDS G...               0.187448
# 7  From Hello to Help, 211 is Here 2.1.1 Get Conn...               0.173179
# 8  ALL ABOUT CIRCUITS Need a Battery Refresher? 9...               0.105081
# 9  UNITED MileagePlus. Get ready and bon voyage U...               0.336201

# %%
df["persuasion_score"] = df["clean_text"].apply(persuasion_score)

# %%
df["persuasion_score"].describe()
# Out:
# count    1000.000000
# mean        0.217312
# std         0.081536
# min         0.029564
# 25%         0.160739
# 50%         0.208714
# 75%         0.262613
# max         0.543086
# Name: persuasion_score, dtype: float64

# %%
df.drop(columns=["persuasion_score_test"], inplace=True)

# %% [markdown]
# ### CTA Score

# %%
df["clean_text"].head(5)
# Out:
# 0    Up to $100 off roundtrip flights to Ireland. T...
# 1    yp The Real ур Yellow Pages Find cheap gas nea...
# 2    Food Navigator USA Plant-based meat: Beyond th...
# 3    MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...
# 4    YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...
# Name: clean_text, dtype: object

# %%
df["clean_text"] = df["clean_text"].fillna("")

# %%
CTA_WORDS = [
    "buy", "shop", "order", "sign up", "signup", "register",
    "download", "click", "start", "get", "try", "apply",
    "claim", "win", "join", "subscribe", "book",

    "buy now", "shop now", "order now", "start now",
    "get started", "join now", "apply now", "book now",
    "reserve now", "enroll now",

    "free trial", "try free", "start free", "get free",
    "free access", "download free", "free preview",
    "no cost", "risk free", "cancel anytime",

    "save now", "get discount", "unlock savings",
    "best deal", "exclusive offer", "special price",
    "flat off", "price drop", "cashback available",
    "grab the deal",

    "limited time", "ends soon", "last chance",
    "act now", "hurry", "don’t miss",
    "today only", "offer expires", "final call",

    "learn more", "explore", "discover",
    "see how it works", "view details",
    "check it out", "find out", "watch demo",

    "get instant access", "claim your offer",
    "buy now and save", "join free today",
    "limited offer act now", "download now it’s free"
]

# %%
## Basic CTA scoring function
def cta_score(text):
    if not isinstance(text, str) or text.strip() == "":
        return 0.0

    text = text.lower()

    hits = sum(1 for word in CTA_WORDS if word in text)

    # normalize: 0 CTAs → 0, 3+ → 1.0
    return min(hits / 3, 1.0)

# %%
test_ads = [
    "BUY NOW and save big",
    "Sign up today to get exclusive access",
    "Food Navigator USA",
    "Click here to download now",
    "Searching for Speakers"
]

for ad in test_ads:
    print(ad, "→", cta_score(ad))
# Out:
# BUY NOW and save big → 1.0
# Sign up today to get exclusive access → 0.6666666666666666
# Food Navigator USA → 0.0
# Click here to download now → 0.6666666666666666
# Searching for Speakers → 0.0

# %%
df["cta_score_test"] = df["clean_text"].head(10).apply(cta_score)
df[["clean_text", "cta_score_test"]].head(10)
# Out:
#                                           clean_text  cta_score_test
# 0  Up to $100 off roundtrip flights to Ireland. T...        1.000000
# 1  yp The Real ур Yellow Pages Find cheap gas nea...        0.333333
# 2  Food Navigator USA Plant-based meat: Beyond th...        0.333333
# 3  MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...        0.000000
# 4  YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...        0.666667
# 5                        ROSELINLIN FREE SHIPPING 10        0.000000
# 6  MENARDS GIFT CARD MENARDS GIFT CARDS MEWARDS G...        0.666667
# 7  From Hello to Help, 211 is Here 2.1.1 Get Conn...        0.333333
# 8  ALL ABOUT CIRCUITS Need a Battery Refresher? 9...        0.333333
# 9  UNITED MileagePlus. Get ready and bon voyage U...        0.666667

# %%
df["cta_score"] = df["clean_text"].apply(cta_score)

# %%
df["cta_score"].value_counts()
# Out:
# cta_score
# 0.000000    396
# 0.333333    356
# 0.666667    185
# 1.000000     63
# Name: count, dtype: int64

# %%
df[
    ["clean_text", "cta_score"]
].sample(10)
# Out:
#                                             clean_text  cta_score
# 504  Take a break from the usual PLAN YOUR VISIT UP...   0.000000
# 997  WIN THIS HOUSE AND START EVERY DAY HERE All to...   0.666667
# 536  FCW INSIDER CHAT Interviews with the 2023 Fede...   0.333333
# 858  Stay productive anywhere, anytime. Boot up in ...   0.333333
# 475  6 KOTAKU AUSTRALIA PODCAST With David and Ruby...   0.000000
# 408  OCHEN TVIS COCOUNTINL 1798 CHENANGO COUNTY NOW...   0.333333
# 64   WHAT'S YOUR NEXT MOVE? Create your own headlin...   0.000000
# 580  FICC Fayetteville Technical Community College ...   0.333333
# 969  WIDE SELECTION OF PRE-OWNED BIKES LOW USED BIK...   0.000000
# 572  ONE VISE TO RULE THEM ALL MULTI-AXIS BENCH-MOU...   0.000000

# %%
df.drop(columns=["cta_score_test"], inplace=True)

# %%
df["clean_text"].head(5)
# Out:
# 0    Up to $100 off roundtrip flights to Ireland. T...
# 1    yp The Real ур Yellow Pages Find cheap gas nea...
# 2    Food Navigator USA Plant-based meat: Beyond th...
# 3    MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...
# 4    YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...
# Name: clean_text, dtype: object

# %%
df["clean_text"] = df["clean_text"].fillna("")

# %%
examples = [
    "Buy now and save big",
    "Searching for speakers",
    "The company has announced a comprehensive strategy to optimize operational efficiency"
]

for text in examples:
    print(text, "→", textstat.flesch_reading_ease(text))
# Out:
# Buy now and save big → 117.16000000000003
# Searching for speakers → 62.79000000000002
# The company has announced a comprehensive strategy to optimize operational efficiency → -19.6754545454545

# %% [markdown]
# ### Readability Score

# %%
def readability_score(text):
    if not isinstance(text, str) or text.strip() == "":
        return 0.5  # neutral fallback

    score = textstat.flesch_reading_ease(text)

    return max(0, min(score / 100, 1))

# %%
df["readability_score_test"] = df["clean_text"].head(10).apply(readability_score)

# %%
df[["clean_text", "readability_score_test"]].head(10)
# Out:
#                                           clean_text  readability_score_test
# 0  Up to $100 off roundtrip flights to Ireland. T...                0.699938
# 1  yp The Real ур Yellow Pages Find cheap gas nea...                0.889050
# 2  Food Navigator USA Plant-based meat: Beyond th...                0.179683
# 3  MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...                0.840504
# 4  YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...                0.452624
# 5                        ROSELINLIN FREE SHIPPING 10                0.758750
# 6  MENARDS GIFT CARD MENARDS GIFT CARDS MEWARDS G...                0.717816
# 7  From Hello to Help, 211 is Here 2.1.1 Get Conn...                0.970014
# 8  ALL ABOUT CIRCUITS Need a Battery Refresher? 9...                0.519229
# 9  UNITED MileagePlus. Get ready and bon voyage U...                0.727200

# %%
df["readability_score"] = df["clean_text"].apply(readability_score)

# %%
df["readability_score"].describe()
# Out:
# count    1000.000000
# mean        0.593930
# std         0.251079
# min         0.000000
# 25%         0.418518
# 50%         0.616373
# 75%         0.782097
# max         1.000000
# Name: readability_score, dtype: float64

# %%
df[["clean_text", "readability_score"]].sample(10)
# Out:
#                                             clean_text  readability_score
# 213              ASHLEY let the light shine shop now →           1.000000
# 941     Essential news from around the world Read More           0.823900
# 35   THE YAMAHA GET OUT AND RIDE SALES EVENT WOLVER...           0.710650
# 34   I I Verified Coupons Available SEE CODES Capit...           0.375452
# 443  THIS SEASON'S OUTSTANDING HAT-TRICK. 5.99% P.A...           0.774164
# 362  the spruce. cleaning Meet Our Print Issue! GET...           0.917800
# 740  Anderson Family Heath-Anderson FUNERAL HOMES &...           0.000000
# 829  Are your cholesterol numbers creeping up? You ...           0.417280
# 170  NEW YORK RANGERS NHLSHOP.COM AF Fanatics Exper...           0.597450
# 543    CBTnuggets On-demand IT training Make IT happen           0.547014

# %%
df.drop(columns=["readability_score_test"], inplace=True)

# %% [markdown]
# ## Final CTR Calculation

# %%
required_cols = [
    "sentiment_score",
    "capital_ratio",
    "persuasion_score",
    "cta_score",
    "readability_score"
]

missing = [c for c in required_cols if c not in df.columns]
missing
# Out:
# []

# %% [raw]
# No missing columns

# %%
df[required_cols] = df[required_cols].fillna(0)

# %%
## Proxy function
def compute_ctr_proxy(row):
    ctr = (
        0.25 * row["sentiment_score"] +
        0.20 * row["capital_ratio"] +
        0.25 * row["persuasion_score"] +
        0.15 * row["cta_score"] +
        0.15 * row["readability_score"]
    )
    return max(0, min(ctr, 1))

# %%
df["ctr_proxy_test"] = df.head(10).apply(compute_ctr_proxy, axis=1)

df[[
        "clean_text",
        "sentiment_score",
        "capital_ratio",
        "persuasion_score",
        "cta_score",
        "readability_score",
        "ctr_proxy_test"
]].head(10)
# Out:
#                                           clean_text  sentiment_score  \
# 0  Up to $100 off roundtrip flights to Ireland. T...              0.5
# 1  yp The Real ур Yellow Pages Find cheap gas nea...              0.5
# 2  Food Navigator USA Plant-based meat: Beyond th...              0.5
# 3  MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...              0.5
# 4  YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...              1.0
# 5                        ROSELINLIN FREE SHIPPING 10              0.5
# 6  MENARDS GIFT CARD MENARDS GIFT CARDS MEWARDS G...              0.5
# 7  From Hello to Help, 211 is Here 2.1.1 Get Conn...              0.5
# 8  ALL ABOUT CIRCUITS Need a Battery Refresher? 9...              0.5
# 9  UNITED MileagePlus. Get ready and bon voyage U...              0.5
#
#    capital_ratio  persuasion_score  cta_score  readability_score  \
# 0       0.037037          0.198016   1.000000           0.699938
# 1       0.098039          0.222818   0.333333           0.889050
# 2       0.600000          0.151504   0.333333           0.179683
# 3       0.407407          0.262872   0.000000           0.840504
# 4       0.277778          0.172790   0.666667           0.452624
# 5       0.600000          0.294787   0.000000           0.758750
# 6       0.600000          0.187448   0.666667           0.717816
# 7       0.142857          0.173179   0.333333           0.970014
# 8       0.565217          0.105081   0.333333           0.519229
# 9       0.047619          0.336201   0.666667           0.727200
#
#    ctr_proxy_test
# 0        0.436902
# 1        0.383670
# 2        0.359828
# 3        0.398275
# 4        0.516646
# 5        0.432509
# 6        0.499534
# 7        0.392368
# 8        0.392198
# 9        0.427654

# %%
df["ctr_proxy"] = df.apply(compute_ctr_proxy, axis=1)

# %%
df["ctr_proxy"].describe()
# Out:
# count    1000.000000
# mean        0.416045
# std         0.102411
# min         0.141852
# 25%         0.349670
# 50%         0.408393
# 75%         0.487074
# max         0.740362
# Name: ctr_proxy, dtype: float64

# %%
def ctr_bucket(ctr):
    if ctr >= 0.6:
        return "High"
    elif ctr >= 0.3:
        return "Medium"
    else:
        return "Low"

df["ctr_bucket"] = df["ctr_proxy"].apply(ctr_bucket)

# %%
df["ctr_bucket"].value_counts()
# Out:
# ctr_bucket
# Medium    836
# Low       123
# High       41
# Name: count, dtype: int64

# %%
df.drop(columns=["ctr_proxy_test"], inplace=True)

# %%
df
# Out:
#                                                   text  dimensions  \
# 0    Up to\n$100 off\nroundtrip\nflights to\nIrelan...  (160, 600)
# 1    yp The Real\nур\nYellow Pages\nFind cheap\ngas...  (300, 250)
# 2    Food Navigator\nUSA\nPlant-based meat:\nBeyond...  (300, 600)
# 3    MONSTROUS\nAIRFLOW\n$20-$23\nDURAMAX\nbanks\n+...  (300, 250)
# 4    YUMMY\nCOMBS\n*\na\nNutriti\nWellne\nNOW\nSafe...   (728, 90)
# ..                                                 ...         ...
# 995  Ochrome OS\nDevice management\nmade simple and...  (300, 600)
# 996  Continue to Recipe\n3 Easy Steps:\n1) Click "C...  (336, 280)
# 997  WIN THIS HOUSE\nAND START\nEVERY DAY HERE\nAll...  (970, 250)
# 998  EVIDENT OLYMPUS\nSZX-AR1 Augmented\nReality Mi...  (300, 250)
# 999  Searching for Speakers?\nCompare\nBefore You B...  (300, 250)
#
#                                             clean_text  num_words  \
# 0    Up to $100 off roundtrip flights to Ireland. T...       27.0
# 1    yp The Real ур Yellow Pages Find cheap gas nea...       51.0
# 2    Food Navigator USA Plant-based meat: Beyond th...       23.0
# 3    MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...       27.0
# 4    YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...       18.0
# ..                                                 ...        ...
# 995  Ochrome OS Device management made simple and s...       22.0
# 996  Continue to Recipe 3 Easy Steps: 1) Click "Con...       19.0
# 997  WIN THIS HOUSE AND START EVERY DAY HERE All to...       15.0
# 998  EVIDENT OLYMPUS SZX-AR1 Augmented Reality Micr...       10.0
# 999  Searching for Speakers? Compare Before You Buy...       13.0
#
#      num_caps_words  capital_ratio  num_exclamations  sentiment_score_test  \
# 0               1.0       0.037037               0.0                   0.5
# 1               5.0       0.098039               1.0                   0.5
# 2              14.0       0.600000               0.0                   0.5
# 3              11.0       0.407407               0.0                   0.5
# 4               5.0       0.277778               2.0                   1.0
# ..              ...            ...               ...                   ...
# 995             1.0       0.045455               0.0                   NaN
# 996             0.0       0.000000               1.0                   NaN
# 997             8.0       0.533333               0.0                   NaN
# 998             3.0       0.300000               0.0                   NaN
# 999             2.0       0.153846               0.0                   NaN
#
#      sentiment_score  persuasion_score  cta_score  readability_score  \
# 0                0.5          0.198016   1.000000           0.699938
# 1                0.5          0.222818   0.333333           0.889050
# 2                0.5          0.151504   0.333333           0.179683
# 3                0.5          0.262872   0.000000           0.840504
# 4                1.0          0.172790   0.666667           0.452624
# ..               ...               ...        ...                ...
# 995              1.0          0.131270   1.000000           0.724917
# 996              1.0          0.089067   0.333333           0.458030
# 997              1.0          0.380776   0.666667           0.920625
# 998              0.5          0.167346   0.000000           0.000000
# 999              0.5          0.253527   0.333333           0.570683
#
#      ctr_proxy ctr_bucket
# 0     0.436902     Medium
# 1     0.383670     Medium
# 2     0.359828     Medium
# 3     0.398275     Medium
# 4     0.516646     Medium
# ..         ...        ...
# 995   0.550646     Medium
# 996   0.390971     Medium
# 997   0.689954       High
# 998   0.226836        Low
# 999   0.354753     Medium
#
# [1000 rows x 14 columns]

# %%
df.head()
# Out:
#                                                 text  dimensions  \
# 0  Up to\n$100 off\nroundtrip\nflights to\nIrelan...  (160, 600)
# 1  yp The Real\nур\nYellow Pages\nFind cheap\ngas...  (300, 250)
# 2  Food Navigator\nUSA\nPlant-based meat:\nBeyond...  (300, 600)
# 3  MONSTROUS\nAIRFLOW\n$20-$23\nDURAMAX\nbanks\n+...  (300, 250)
# 4  YUMMY\nCOMBS\n*\na\nNutriti\nWellne\nNOW\nSafe...   (728, 90)
#
#                                           clean_text  num_words  \
# 0  Up to $100 off roundtrip flights to Ireland. T...       27.0
# 1  yp The Real ур Yellow Pages Find cheap gas nea...       51.0
# 2  Food Navigator USA Plant-based meat: Beyond th...       23.0
# 3  MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...       27.0
# 4  YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...       18.0
#
#    num_caps_words  capital_ratio  num_exclamations  sentiment_score_test  \
# 0             1.0       0.037037               0.0                   0.5
# 1             5.0       0.098039               1.0                   0.5
# 2            14.0       0.600000               0.0                   0.5
# 3            11.0       0.407407               0.0                   0.5
# 4             5.0       0.277778               2.0                   1.0
#
#    sentiment_score  persuasion_score  cta_score  readability_score  ctr_proxy  \
# 0              0.5          0.198016   1.000000           0.699938   0.436902
# 1              0.5          0.222818   0.333333           0.889050   0.383670
# 2              0.5          0.151504   0.333333           0.179683   0.359828
# 3              0.5          0.262872   0.000000           0.840504   0.398275
# 4              1.0          0.172790   0.666667           0.452624   0.516646
#
#   ctr_bucket
# 0     Medium
# 1     Medium
# 2     Medium
# 3     Medium
# 4     Medium

# %%
df.tail()
# Out:
#                                                   text  dimensions  \
# 995  Ochrome OS\nDevice management\nmade simple and...  (300, 600)
# 996  Continue to Recipe\n3 Easy Steps:\n1) Click "C...  (336, 280)
# 997  WIN THIS HOUSE\nAND START\nEVERY DAY HERE\nAll...  (970, 250)
# 998  EVIDENT OLYMPUS\nSZX-AR1 Augmented\nReality Mi...  (300, 250)
# 999  Searching for Speakers?\nCompare\nBefore You B...  (300, 250)
#
#                                             clean_text  num_words  \
# 995  Ochrome OS Device management made simple and s...       22.0
# 996  Continue to Recipe 3 Easy Steps: 1) Click "Con...       19.0
# 997  WIN THIS HOUSE AND START EVERY DAY HERE All to...       15.0
# 998  EVIDENT OLYMPUS SZX-AR1 Augmented Reality Micr...       10.0
# 999  Searching for Speakers? Compare Before You Buy...       13.0
#
#      num_caps_words  capital_ratio  num_exclamations  sentiment_score_test  \
# 995             1.0       0.045455               0.0                   NaN
# 996             0.0       0.000000               1.0                   NaN
# 997             8.0       0.533333               0.0                   NaN
# 998             3.0       0.300000               0.0                   NaN
# 999             2.0       0.153846               0.0                   NaN
#
#      sentiment_score  persuasion_score  cta_score  readability_score  \
# 995              1.0          0.131270   1.000000           0.724917
# 996              1.0          0.089067   0.333333           0.458030
# 997              1.0          0.380776   0.666667           0.920625
# 998              0.5          0.167346   0.000000           0.000000
# 999              0.5          0.253527   0.333333           0.570683
#
#      ctr_proxy ctr_bucket
# 995   0.550646     Medium
# 996   0.390971     Medium
# 997   0.689954       High
# 998   0.226836        Low
# 999   0.354753     Medium

# %%
df.head()
# Out:
#                                                 text  dimensions  \
# 0  Up to\n$100 off\nroundtrip\nflights to\nIrelan...  (160, 600)
# 1  yp The Real\nур\nYellow Pages\nFind cheap\ngas...  (300, 250)
# 2  Food Navigator\nUSA\nPlant-based meat:\nBeyond...  (300, 600)
# 3  MONSTROUS\nAIRFLOW\n$20-$23\nDURAMAX\nbanks\n+...  (300, 250)
# 4  YUMMY\nCOMBS\n*\na\nNutriti\nWellne\nNOW\nSafe...   (728, 90)
#
#                                           clean_text  num_words  \
# 0  Up to $100 off roundtrip flights to Ireland. T...       27.0
# 1  yp The Real ур Yellow Pages Find cheap gas nea...       51.0
# 2  Food Navigator USA Plant-based meat: Beyond th...       23.0
# 3  MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...       27.0
# 4  YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...       18.0
#
#    num_caps_words  capital_ratio  num_exclamations  sentiment_score_test  \
# 0             1.0       0.037037               0.0                   0.5
# 1             5.0       0.098039               1.0                   0.5
# 2            14.0       0.600000               0.0                   0.5
# 3            11.0       0.407407               0.0                   0.5
# 4             5.0       0.277778               2.0                   1.0
#
#    sentiment_score  persuasion_score  cta_score  readability_score  ctr_proxy  \
# 0              0.5          0.198016   1.000000           0.699938   0.436902
# 1              0.5          0.222818   0.333333           0.889050   0.383670
# 2              0.5          0.151504   0.333333           0.179683   0.359828
# 3              0.5          0.262872   0.000000           0.840504   0.398275
# 4              1.0          0.172790   0.666667           0.452624   0.516646
#
#   ctr_bucket
# 0     Medium
# 1     Medium
# 2     Medium
# 3     Medium
# 4     Medium

# %%
df.head(20)
# Out:
#                                                  text  dimensions  \
# 0   Up to\n$100 off\nroundtrip\nflights to\nIrelan...  (160, 600)
# 1   yp The Real\nур\nYellow Pages\nFind cheap\ngas...  (300, 250)
# 2   Food Navigator\nUSA\nPlant-based meat:\nBeyond...  (300, 600)
# 3   MONSTROUS\nAIRFLOW\n$20-$23\nDURAMAX\nbanks\n+...  (300, 250)
# 4   YUMMY\nCOMBS\n*\na\nNutriti\nWellne\nNOW\nSafe...   (728, 90)
# 5                       ROSELINLIN\nFREE SHIPPING\n10  (970, 250)
# 6   MENARDS\nGIFT CARD\nMENARDS\nGIFT CARDS\nMEWAR...  (300, 250)
# 7   From Hello\nto Help,\n211 is Here\n2.1.1\nGet ...  (300, 250)
# 8   ALL ABOUT\nCIRCUITS\nNeed a Battery\nRefresher...  (300, 250)
# 9   UNITED\nMileagePlus.\nGet ready and bon voyage...  (300, 250)
# 10  hfa rumblefish\nSTREAMLINE YOUR MUSIC\nROYALTI...  (300, 250)
# 11  BANANA\nREPUBLIC\nFACTORY\n280+ NEW ARRIVALS\n...   (728, 90)
# 12  MULLINS\nWHEY\n100% Whey\nProtein Isolate\nrBG...  (970, 250)
# 13  logitech\nNEVER SEE THE LIGHT\nOF DAY AGAIN.\n...  (300, 250)
# 14  Capital One Shopping\nThe coupon-finding\nbrow...   (728, 90)
# 15  TEK HDMI 2.1\nHDMI\nLATRA\nCERTIFIED\nCABLE\nR...  (300, 250)
# 16  Free trial\nEnterprise-caliber\nIT service des...  (336, 280)
# 17  MAKE\nYOUR\nMOVE\nwith the\nmost\ntrusted\nbra...  (300, 250)
# 18  2022\nMARCH 10-12\nNEW ORLEANS\nTHE FUTURE IS\...  (300, 250)
# 19  SENTARAⓇ\nYou derserve\nTHE BEST\nYou're\nsafe...  (970, 250)
#
#                                            clean_text  num_words  \
# 0   Up to $100 off roundtrip flights to Ireland. T...       27.0
# 1   yp The Real ур Yellow Pages Find cheap gas nea...       51.0
# 2   Food Navigator USA Plant-based meat: Beyond th...       23.0
# 3   MONSTROUS AIRFLOW $20-$23 DURAMAX banks +27% B...       27.0
# 4   YUMMY COMBS * a Nutriti Wellne NOW Safest, Mos...       18.0
# 5                         ROSELINLIN FREE SHIPPING 10        4.0
# 6   MENARDS GIFT CARD MENARDS GIFT CARDS MEWARDS G...       19.0
# 7   From Hello to Help, 211 is Here 2.1.1 Get Conn...       14.0
# 8   ALL ABOUT CIRCUITS Need a Battery Refresher? 9...       23.0
# 9   UNITED MileagePlus. Get ready and bon voyage U...       21.0
# 10  hfa rumblefish STREAMLINE YOUR MUSIC ROYALTIES...        8.0
# 11  BANANA REPUBLIC FACTORY 280+ NEW ARRIVALS from...       10.0
# 12  MULLINS WHEY 100% Whey Protein Isolate rBGH | ...       30.0
# 13  logitech NEVER SEE THE LIGHT OF DAY AGAIN. SMA...       16.0
# 14  Capital One Shopping The coupon-finding browse...       21.0
# 15  TEK HDMI 2.1 HDMI LATRA CERTIFIED CABLE RE DO ...       27.0
# 16  Free trial Enterprise-caliber IT service desk ...       16.0
# 17  MAKE YOUR MOVE with the most trusted brands in...       21.0
# 18  2022 MARCH 10-12 NEW ORLEANS THE FUTURE IS IN ...       11.0
# 19  SENTARAⓇ You derserve THE BEST You're safe at ...       21.0
#
#     num_caps_words  capital_ratio  num_exclamations  sentiment_score_test  \
# 0              1.0       0.037037               0.0                   0.5
# 1              5.0       0.098039               1.0                   0.5
# 2             14.0       0.600000               0.0                   0.5
# 3             11.0       0.407407               0.0                   0.5
# 4              5.0       0.277778               2.0                   1.0
# 5              3.0       0.600000               0.0                   0.5
# 6             19.0       0.600000               1.0                   0.5
# 7              2.0       0.142857               0.0                   0.5
# 8             13.0       0.565217               1.0                   0.5
# 9              1.0       0.047619               0.0                   0.5
# 10             6.0       0.600000               0.0                   NaN
# 11             7.0       0.600000               0.0                   NaN
# 12             8.0       0.266667               0.0                   NaN
# 13            14.0       0.600000               0.0                   NaN
# 14             5.0       0.238095               0.0                   NaN
# 15            25.0       0.600000               0.0                   NaN
# 16             1.0       0.062500               1.0                   NaN
# 17             5.0       0.238095               0.0                   NaN
# 18             9.0       0.600000               0.0                   NaN
# 19             5.0       0.238095               0.0                   NaN
#
#     sentiment_score  persuasion_score  cta_score  readability_score  \
# 0               0.5          0.198016   1.000000           0.699938
# 1               0.5          0.222818   0.333333           0.889050
# 2               0.5          0.151504   0.333333           0.179683
# 3               0.5          0.262872   0.000000           0.840504
# 4               1.0          0.172790   0.666667           0.452624
# 5               0.5          0.294787   0.000000           0.758750
# 6               0.5          0.187448   0.666667           0.717816
# 7               0.5          0.173179   0.333333           0.970014
# 8               0.5          0.105081   0.333333           0.519229
# 9               0.5          0.336201   0.666667           0.727200
# 10              1.0          0.207520   0.000000           0.400900
# 11              0.5          0.405035   0.666667           0.494800
# 12              0.5          0.189133   0.333333           0.552658
# 13              0.0          0.147494   0.666667           0.771025
# 14              1.0          0.271555   1.000000           0.243771
# 15              0.5          0.198487   0.000000           0.629667
# 16              0.5          0.112335   0.666667           0.612400
# 17              1.0          0.187447   0.000000           0.753204
# 18              0.5          0.216725   0.000000           0.879973
# 19              1.0          0.207079   0.000000           0.471204
#
#     ctr_proxy ctr_bucket
# 0    0.436902     Medium
# 1    0.383670     Medium
# 2    0.359828     Medium
# 3    0.398275     Medium
# 4    0.516646     Medium
# 5    0.432509     Medium
# 6    0.499534     Medium
# 7    0.392368     Medium
# 8    0.392198     Medium
# 9    0.427654     Medium
# 10   0.482015     Medium
# 11   0.520479     Medium
# 12   0.358515     Medium
# 13   0.372527     Medium
# 14   0.552073     Medium
# 15   0.389072     Medium
# 16   0.357444     Medium
# 17   0.457461     Medium
# 18   0.431177     Medium
# 19   0.420069     Medium
